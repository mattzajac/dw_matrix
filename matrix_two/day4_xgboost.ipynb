# %%
# !pip install --upgrade tables
# !pip install eli5
# !pip install xgboost
# Out:
# Collecting tables
#   Downloading https://files.pythonhosted.org/packages/ed/c3/8fd9e3bb21872f9d69eb93b3014c86479864cca94e625fd03713ccacec80/tables-3.6.1-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 2.8MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /usr/local/lib/python3.6/dist-packages (from tables) (1.17.5)
# Requirement already satisfied, skipping upgrade: numexpr>=2.6.2 in /usr/local/lib/python3.6/dist-packages (from tables) (2.7.1)
# Installing collected packages: tables
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.6.1
# Collecting eli5
#   Downloading https://files.pythonhosted.org/packages/97/2f/c85c7d8f8548e460829971785347e14e45fa5c6617da374711dec8cb38cc/eli5-0.10.1-py2.py3-none-any.whl (105kB)
#      |████████████████████████████████| 112kB 2.4MB/s
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from eli5) (0.10.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from eli5) (1.12.0)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.6/dist-packages (from eli5) (0.22.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from eli5) (1.4.1)
# Requirement already satisfied: attrs>16.0.0 in /usr/local/lib/python3.6/dist-packages (from eli5) (19.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from eli5) (2.11.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.6/dist-packages (from eli5) (0.8.6)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from eli5) (1.17.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18->eli5) (0.14.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->eli5) (1.1.1)
# Installing collected packages: eli5
# Successfully installed eli5-0.10.1
# Requirement already satisfied: xgboost in /usr/local/lib/python3.6/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from xgboost) (1.17.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from xgboost) (1.4.1)

# %%
import pandas as pd
import numpy as np

from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb

from sklearn.metrics import mean_absolute_error as mae
from sklearn.model_selection import cross_val_score, KFold

import eli5
from eli5.sklearn import PermutationImportance

# %%
cd '/content/drive/My Drive/Colab Notebooks/dw_matrix'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
df = pd.read_hdf('data/car.h5')

# %%
df = df[ df.price_currency != 'EUR' ]

# %%
df.rename(columns = {'param_model-pojazdu':'param_model_pojazdu',
                     'param_liczba-drzwi' : 'param_liczba_drzwi'}, inplace = True)

# %%
df['param_liczba_drzwi'].fillna(-1, inplace = True)
df['param_liczba_drzwi'] = df['param_liczba_drzwi'].astype(np.int8)

# %%
suffix = '__cat'

for feat in df.columns:
  if isinstance(df[feat][0], list):
    continue
  factorized_vals = df[feat].factorize()[0]
  if suffix in feat:
    df[feat] = factorized_vals
  else:
    df[feat + suffix] = factorized_vals

# %%
cat_feats = [x for x in df.columns if suffix in x]
cat_feats = [x for x in cat_feats if 'price' not in x]

# %%
def run_model(model, feats):
  X = df[feats].values
  y = df['price_value'].values

  scores = cross_val_score(model, X, y, cv=3, scoring='neg_mean_absolute_error')
  return np.mean(scores), np.std(scores)

# %% [markdown]
# ### Decision Tree Model

# %%
run_model( DecisionTreeRegressor(max_depth=5), cat_feats )
# Out:
# (-19566.588937368324, 90.6181486516617)

# %% [markdown]
# ### Random Forest Model

# %%
model = RandomForestRegressor(max_depth=5, n_estimators=50, random_state=2020)
run_model(model, cat_feats)
# Out:
# (-18801.110116978012, 138.10063905479723)

# %% [markdown]
# ### XGBoost Model

# %%
xgb_params = {
    'max_depth': 5, 
    'n_estimators': 50, 
    'learning_rate': 0.1,
    'seed': 2020
    }

model = xgb.XGBRegressor(**xgb_params)
run_model(model, cat_feats)
# Out:
# [12:06:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:06:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:07:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-13039.290196724838, 109.36715375706265)

# %%
X = df[cat_feats].values
y = df['price_value'].values

m = xgb.XGBRegressor(**xgb_params)
m.fit(X, y)

imp = PermutationImportance(m, random_state=2020).fit(X, y)
eli5.show_weights(imp, feature_names=cat_feats)
# Out:
# [12:07:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1206
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_napęd__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1182
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_rok-produkcji__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1112
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_stan__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0639
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_skrzynia-biegów__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0532
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_faktura-vat__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0457
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_moc__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0273
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_marka-pojazdu__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0234
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_typ__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0231
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 feature_kamera-cofania__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0191
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_pojemność-skokowa__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0150
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 seller_name__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0141
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_kod-silnika__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0128
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_model_pojazdu__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0120
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 feature_wspomaganie-kierownicy__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0110
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_wersja__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0094
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 feature_czujniki-parkowania-przednie__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0089
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 feature_asystent-pasa-ruchu__cat
#             </td>
#         </tr>
#
#         <tr style="ba

# %%
feats = ['param_napęd__cat','param_rok-produkcji__cat','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc__cat','param_marka-pojazdu__cat',
         'param_typ__cat','feature_kamera-cofania__cat','param_pojemność-skokowa__cat','seller_name__cat','param_kod-silnika__cat','param_model_pojazdu__cat',
         'feature_wspomaganie-kierownicy__cat','param_wersja__cat','feature_czujniki-parkowania-przednie__cat','feature_asystent-pasa-ruchu__cat','feature_system-start-stop__cat',
         'feature_regulowane-zawieszenie__cat','feature_światła-led__cat']

# %%
run_model(model, feats)
# Out:
# [12:13:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-13240.835942843716, 95.7039217631258)

# %%
df['param_rok-produkcji'].unique()
# Out:
# array(['2018', '2011', '2015', '2009', '2017', '2012', '2013', '2007',
#        '2001', '2016', '2006', '2008', '2004', '1999', '2000', '2010',
#        '2005', '2002', '1998', '2014', '2003', '1982', '1995', '1997',
#        '1992', '1993', '1994', '1996', '1989', '1988', '1967', '1987',
#        '1959', '1990', '1991', '1974', None, '1975', '1973', '1985',
#        '1984', '1986', '1981', '1979', '1960', '1983', '1978', '1964',
#        '1980', '1972', '1969', '1956', '1966', '1977', '1971', '1963',
#        '1953', '1961', '1952', '1949', '1976', '1965', '1937', '1968',
#        '1958', '1962', '1955', '1970', '1933', '1929', '1957', '1944',
#        '1954', '1932', '1936', '1947', '1948'], dtype=object)

# %%
df['param_rok-produkcji'] = df['param_rok-produkcji'].map(lambda x: -1 if str(x) == 'None' else int(x))

# %%
df['param_rok-produkcji'].unique()
# Out:
# array([2018, 2011, 2015, 2009, 2017, 2012, 2013, 2007, 2001, 2016, 2006,
#        2008, 2004, 1999, 2000, 2010, 2005, 2002, 1998, 2014, 2003, 1982,
#        1995, 1997, 1992, 1993, 1994, 1996, 1989, 1988, 1967, 1987, 1959,
#        1990, 1991, 1974,   -1, 1975, 1973, 1985, 1984, 1986, 1981, 1979,
#        1960, 1983, 1978, 1964, 1980, 1972, 1969, 1956, 1966, 1977, 1971,
#        1963, 1953, 1961, 1952, 1949, 1976, 1965, 1937, 1968, 1958, 1962,
#        1955, 1970, 1933, 1929, 1957, 1944, 1954, 1932, 1936, 1947, 1948])

# %%
feats = ['param_napęd__cat','param_rok-produkcji','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc__cat','param_marka-pojazdu__cat',
         'param_typ__cat','feature_kamera-cofania__cat','param_pojemność-skokowa__cat','seller_name__cat','param_kod-silnika__cat','param_model_pojazdu__cat',
         'feature_wspomaganie-kierownicy__cat','param_wersja__cat','feature_czujniki-parkowania-przednie__cat','feature_asystent-pasa-ruchu__cat','feature_system-start-stop__cat',
         'feature_regulowane-zawieszenie__cat','feature_światła-led__cat']

# %%
run_model(model, feats)
# Out:
# [12:13:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-11197.83713694348, 98.22041147876314)

# %%
df['param_moc'].unique()
# Out:
# array(['90 KM', '115 KM', '262 KM', '110 KM', '310 KM', '105 KM',
#        '140 KM', '175 KM', '125 KM', '185 KM', '190 KM', '440 KM',
#        '141 KM', '200 KM', '224 KM', '75 KM', '99 KM', '184 KM', '109 KM',
#        '233 KM', '116 KM', '68 KM', '286 KM', '126 KM', '160 KM',
#        '135 KM', '120 KM', '272 KM', None, '150 KM', '180 KM', '136 KM',
#        '102 KM', '131 KM', '218 KM', '245 KM', '170 KM', '112 KM',
#        '250 KM', '252 KM', '73 KM', '100 KM', '313 KM', '101 KM',
#        '285 KM', '70 KM', '383 KM', '174 KM', '277 KM', '132 KM',
#        '130 KM', '215 KM', '60 KM', '330 KM', '163 KM', '177 KM', '98 KM',
#        '78 KM', '189 KM', '156 KM', '143 KM', '69 KM', '113 KM', '65 KM',
#        '122 KM', '82 KM', '251 KM', '95 KM', '197 KM', '235 KM', '238 KM',
#        '171 KM', '381 KM', '400 KM', '178 KM', '80 KM', '165 KM', '85 KM',
#        '258 KM', '142 KM', '204 KM', '124 KM', '55 KM', '144 KM',
#        '231 KM', '248 KM', '152 KM', '181 KM', '210 KM', '340 KM',
#        '129 KM', '147 KM', '50 KM', '54 KM', '290 KM', '306 KM', '193 KM',
#        '77 KM', '164 KM', '96 KM', '194 KM', '111 KM', '166 KM', '206 KM',
#        '118 KM', '360 KM', '211 KM', '271 KM', '455 KM', '280 KM',
#        '106 KM', '114 KM', '421 KM', '74 KM', '213 KM', '121 KM',
#        '275 KM', '435 KM', '384 KM', '326 KM', '88 KM', '220 KM',
#        '260 KM', '64 KM', '86 KM', '128 KM', '256 KM', '240 KM', '244 KM',
#        '162 KM', '237 KM', '350 KM', '35 KM', '265 KM', '202 KM',
#        '133 KM', '83 KM', '117 KM', '146 KM', '92 KM', '192 KM', '145 KM',
#        '525 KM', '254 KM', '182 KM', '328 KM', '367 KM', '148 KM',
#        '456 KM', '97 KM', '270 KM', '107 KM', '108 KM', '203 KM',
#        '155 KM', '94 KM', '93 KM', '241 KM', '20 KM', '71 KM', '173 KM',
#        '58 KM', '205 KM', '236 KM', '1 400 KM', '557 KM', '84 KM',
#        '457 KM', '72 KM', '295 KM', '134 KM', '425 KM', '228 KM', '81 KM',
#        '230 KM', '201 KM', '87 KM', '234 KM', '299 KM', '585 KM',
#        '209 KM', '370 KM', '6 600 KM', '305 KM', '382 KM', '560 KM',
#        '158 KM', '176 KM', '320 KM', '225 KM', '62 KM', '255 KM',
#        '300 KM', '354 KM', '45 KM', '420 KM', '510 KM', '243 KM',
#        '239 KM', '468 KM', '409 KM', '24 KM', '335 KM', '605 KM',
#        '410 KM', '416 KM', '183 KM', '303 KM', '59 KM', '4 KM', '283 KM',
#        '385 KM', '104 KM', '127 KM', '278 KM', '344 KM', '365 KM',
#        '333 KM', '680 KM', '161 KM', '195 KM', '214 KM', '66 KM',
#        '170 000 KM', '219 KM', '89 KM', '41 KM', '249 KM', '388 KM',
#        '103 KM', '217 KM', '570 KM', '625 KM', '364 KM', '450 KM',
#        '138 KM', '253 KM', '67 KM', '157 KM', '405 KM', '517 KM',
#        '319 KM', '612 KM', '188 KM', '710 KM', '274 KM', '186 KM',
#        '139 KM', '11 000 KM', '1 006 KM', '153 KM', '1 430 KM', '323 KM',
#        '430 KM', '329 KM', '196 KM', '57 KM', '507 KM', '207 KM',
#        '489 KM', '460 KM', '408 KM', '308 KM', '359 KM', '312 KM',
#        '179 600 KM', '149 KM', '550 KM', '520 KM', '380 KM', '297 KM',
#        '347 KM', '259 KM', '212 KM', '343 KM', '309 KM', '53 KM',
#        '169 KM', '208 KM', '76 KM', '449 KM', '47 KM', '338 KM',
#        '1 995 KM', '470 KM', '151 KM', '168 KM', '600 KM', '660 KM',
#        '48 KM', '264 KM', '315 KM', '232 KM', '63 KM', '630 KM', '51 KM',
#        '1 156 KM', '351 KM', '442 KM', '191 KM', '5 KM', '91 KM', '21 KM',
#        '407 KM', '284 KM', '346 KM', '717 KM', '276 KM', '431 KM',
#        '179 KM', '223 KM', '40 KM', '325 KM', '11 KM', '268 KM', '640 KM',
#        '292 KM', '1 KM', '316 KM', '477 KM', '11 555 KM', '167 KM',
#        '390 KM', '226 KM', '317 KM', '172 KM', '187 KM', '1 005 KM',
#        '500 KM', '6 934 KM', '289 KM', '345 KM', '558 KM', '267 KM',
#        '540 KM', '9 KM', '279 KM', '334 KM', '137 KM', '287 KM', '10 KM',
#        '401 KM', '199 KM', '544 KM', '298 KM', '394 KM', '780 KM',
#        '123 KM', '530 KM', '426 KM', '307 KM', '222 KM', '79 KM',
#        '399 KM', '263 KM', '327 KM', '198 KM', '1 998 KM', '404 KM',
#        '30 KM', '502 KM', '469 KM', '1 122 KM', '3 KM', '386 KM', '61 KM',
#        '154 KM', '269 KM', '10 731 KM', '311 KM', '480 KM', '376 KM',
#        '519 KM', '361 KM', '770 KM', '453 KM', '1 600 KM', '281 KM',
#        '294 KM', '441 KM', '332 KM', '247 KM', '227 KM', '800 KM',
#        '288 KM', '337 KM', '324 KM', '362 KM', '23 KM', '242 KM',
#        '357 KM', '39 KM', '575 KM', '998 KM', '273 KM', '56 KM', '119 KM',
#        '462 KM', '43 KM', '355 KM', '52 KM', '387 KM', '566 KM', '12 KM',
#        '439 KM', '352 KM', '422 KM', '296 KM', '304 KM', '555 KM',
#        '551 KM', '485 KM', '42 KM', '610 KM', '397 KM', '221 KM',
#        '348 KM', '432 KM', '37 KM', '349 KM', '302 KM', '356 KM',
#        '2 100 KM', '476 KM', '975 KM', '369 KM', '486 KM', '246 KM',
#        '3 700 KM', '372 KM', '318 KM', '395 KM', '514 KM', '14 800 KM',
#        '406 KM', '412 KM', '8 498 KM', '342 KM', '9 000 KM', '1 254 KM',
#        '445 KM', '13 KM', '2 800 KM', '229 KM', '282 KM', '495 KM',
#        '378 KM', '490 KM', '368 KM', '472 KM', '375 KM', '7 500 KM',
#        '363 KM', '650 KM', '159 KM', '1 110 KM', '44 KM', '434 KM',
#        '571 KM', '543 848 KM', '707 KM', '301 KM', '2 000 KM', '216 KM',
#        '1 100 KM', '36 KM', '266 KM', '2 300 KM', '609 KM', '46 KM',
#        '1 116 KM', '1 300 KM', '900 KM', '339 KM', '475 KM', '565 KM',
#        '396 KM', '8 500 KM', '465 KM', '685 KM', '437 KM', '257 KM',
#        '5 100 KM', '371 KM', '2 938 KM', '492 KM', '411 KM', '526 KM',
#        '27 KM', '8 KM', '549 KM', '12 648 KM', '261 KM', '177 000 KM',
#        '10 000 KM', '293 KM', '1 984 KM', '2 018 KM', '175 000 KM',
#        '1 900 KM', '1 360 KM', '581 KM', '1 781 KM', '28 KM',
#        '174 000 KM', '501 KM', '504 KM', '31 KM', '1 991 KM', '466 KM',
#        '576 KM', '9 600 KM', '415 KM', '7 700 KM', '10 500 KM',
#        '1 198 KM', '799 KM', '18 KM', '447 KM', '366 KM', '15 KM',
#        '2 465 KM', '580 KM', '1 136 KM', '136 000 KM', '11 200 KM',
#        '590 KM', '564 KM', '1 000 KM', '1 500 KM', '38 KM', '291 KM',
#        '2 840 KM', '2 311 KM', '1 424 KM', '745 KM', '14 KM', '321 KM',
#        '436 KM', '314 KM', '584 KM', '336 KM', '25 KM', '140 000 KM',
#        '531 KM', '2 KM', '1 540 KM', '529 KM', '467 KM', '478 KM',
#        '8 568 KM', '322 KM', '140 105 KM'], dtype=object)

# %%
df['param_moc'] = df['param_moc'].map( lambda x: -1 if str(x) == 'None' else int(x.split(' ')[0]) )

# %%
feats = ['param_napęd__cat','param_rok-produkcji','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc','param_marka-pojazdu__cat',
         'param_typ__cat','feature_kamera-cofania__cat','param_pojemność-skokowa__cat','seller_name__cat','param_kod-silnika__cat','param_model_pojazdu__cat',
         'feature_wspomaganie-kierownicy__cat','param_wersja__cat','feature_czujniki-parkowania-przednie__cat','feature_asystent-pasa-ruchu__cat','feature_system-start-stop__cat',
         'feature_regulowane-zawieszenie__cat','feature_światła-led__cat']

# %%
run_model(model, feats)
# Out:
# [12:13:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:13:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-9602.94111071797, 57.96672683246094)

# %%
df['param_pojemność-skokowa'].unique()
# Out:
# array(['898 cm3', '1 560 cm3', '3 000 cm3', ..., '5 992 cm3', '1 966 cm3',
#        '142 280 cm3'], dtype=object)

# %%
df['param were_pojemność-skokowa'] = df['param_pojemność-skokowa'].map( lambda x: -1 if str(x) == 'None' elese int(str(x).split('cm')[0].replace(' ','')) )

# %%
df['param_pojemność-skokowa'].unique()
# Out:
# array([   898,   1560,   3000, ...,   5992,   1966, 142280])

# %%
feats = ['param_napęd__cat','param_rok-produkcji','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc','param_marka-pojazdu__cat',
         'param_typ__cat','feature_kamera-cofania__cat','param_pojemność-skokowa','seller_name__cat','param_kod-silnika__cat','param_model_pojazdu__cat',
         'feature_wspomaganie-kierownicy__cat','param_wersja__cat','feature_czujniki-parkowania-przednie__cat','feature_asystent-pasa-ruchu__cat','feature_system-start-stop__cat',
         'feature_regulowane-zawieszenie__cat','feature_światła-led__cat']

# %%
run_model(model, feats)
# Out:
# [12:14:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:14:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:14:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-9449.513980284812, 81.47168211987172)

# %%
# Some cleaning
# df.loc[df.param_typ == 'compact/sedan', 'param_typ'] = 'Sedan'

# %% [markdown]
# #Read cleaned dataframe

# %%
cd '/content/drive/My Drive/Colab Notebooks/dw_matrix/data'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/data

# %%
df = pd.read_hdf('car_data.h5')

# %%
df['param_typ__cat'] = df['param_typ'].factorize()[0]

# %%
df.rename(columns = {'param_skrzynia-biegów':'param_skrzynia_biegów'}, inplace = True)

# %%
[x for x in df.columns if 'przebieg' in x]
# Out:
# ['param_przebieg', 'param_przebieg__cat']

# %%
df.param_przebieg.unique()
# Out:
# array(['1 km', '209 533 km', '30 500 km', ..., '95 148 km', '159 248 km',
#        '74 700 km'], dtype=object)

# %%
df.param_gearbox.unique()
# Out:
# array([None, 'Manualna', 'Automatyczna hydrauliczna (klasyczna)',
#        'Automatyczna dwusprzęgłowa (DCT, DSG)',
#        'Automatyczna bezstopniowa (CVT)',
#        'Półautomatyczna (ASG, Tiptronic)'], dtype=object)

# %%
df['param_przebieg_num'] = df['param_przebieg'].map( lambda x: -1 if str(x) == 'None' else int(str(x).split('km')[0].replace(' ', '')) )

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106290 entries, 0 to 160615
# Data columns (total 310 columns):
# breadcrumb                                            object
# created_at                                            object
# price_currency                                        object
# price_details                                         object
# price_value                                           object
# seller_address                                        object
# seller_name                                           object
# seller_type                                           object
# feature_czujniki-parkowania-przednie                  bool
# feature_poduszka-powietrzna-chroniąca-kolana          bool
# feature_kurtyny-powietrzne                            bool
# feature_klimatyzacja-dwustrefowa                      bool
# feature_światła-led                                   bool
# feature_czujnik-zmierzchu                             bool
# feature_elektrycznie-ustawiane-lusterka               bool
# feature_asr-(kontrola-trakcji)                        bool
# feature_poduszka-powietrzna-kierowcy                  bool
# feature_cd                                            bool
# feature_elektryczne-szyby-przednie                    bool
# feature_poduszka-powietrzna-pasażera                  bool
# feature_system-start-stop                             bool
# feature_światła-do-jazdy-dziennej                     bool
# feature_komputer-pokładowy                            bool
# feature_elektryczne-szyby-tylne                       bool
# feature_klimatyzacja-manualna                         bool
# feature_tapicerka-welurowa                            bool
# feature_czujnik-deszczu                               bool
# feature_światła-przeciwmgielne                        bool
# feature_ogrzewanie-postojowe                          bool
# feature_radio-niefabryczne                            bool
# feature_regulowane-zawieszenie                        bool
# feature_ogranicznik-prędkości                         bool
# feature_zmieniarka-cd                                 bool
# feature_szyberdach                                    bool
# feature_isofix                                        bool
# feature_asystent-pasa-ruchu                           bool
# feature_alufelgi                                      bool
# feature_bluetooth                                     bool
# feature_nawigacja-gps                                 bool
# feature_asystent-parkowania                           bool
# feature_wspomaganie-kierownicy                        bool
# feature_podgrzewana-przednia-szyba                    bool
# feature_przyciemniane-szyby                           bool
# feature_elektrycznie-ustawiane-fotele                 bool
# feature_klimatyzacja-czterostrefowa                   bool
# feature_tuner-tv                                      bool
# feature_poduszki-boczne-przednie                      bool
# feature_tempomat-aktywny                              bool
# feature_klimatyzacja-automatyczna                     bool
# feature_poduszki-boczne-tylne                         bool
# feature_radio-fabryczne                               bool
# feature_odtwarzacz-dvd                                bool
# feature_czujniki-parkowania-tylne                     bool
# feature_łopatki-zmiany-biegów                         bool
# feature_centralny-zamek                               bool
# feature_dach-panoramiczny                             bool
# feature_kamera-cofania                                bool
# feature_immobilizer                                   bool
# feature_czujnik-martwego-pola                         bool
# feature_gniazdo-sd                                    bool
# feature_podgrzewane-lusterka-boczne                   bool
# feature_podgrzewane-przednie-siedzenia                bool
# feature_hak                                           bool
# feature_abs                                           bool
# feature_wielofunkcyjna-kierownica                     bool
# feature_światła-xenonowe                              bool
# feature_gniazdo-usb                                   bool
# feature_tapicerka-skórzana                            bool
# feature_gniazdo-aux                                   bool
# feature_esp-(stabilizacja-toru-jazdy)                 bool
# feature_alarm                                         bool
# feature_podgrzewane-tylne-siedzenia                   bool
# feature_mp3                                           bool
# feature_tempomat                                      bool
# feature_hud-(wyświetlacz-przezierny)                  bool
# feature_elektrochromatyczne-lusterko-wsteczne         bool
# feature_relingi-dachowe                               bool
# feature_elektrochromatyczne-lusterka-boczne           bool
# param_liczba-miejsc                                   object
# param_uszkodzony                                      object
# param_marka-pojazdu                                   object
# param_model                                           object
# param_engine-code                                     object
# param_liczba_drzwi                                    int8
# param_first-registration                              object
# param_country-of-origin                               object
# param_pierwsza-rejestracja                            object
# param_gearbox                                         object
# param_przebieg                                        object
# param_faktura-vat                                     object
# param_rok-produkcji                                   int64
# param_vin                                             object
# param_perłowy                                         object
# param_homologacja-ciężarowa                           object
# param_service-record                                  object
# param_metallic                                        object
# param_leasing-concession                              object
# param_color                                           object
# param_financing-option                                object
# param_original-owner                                  object
# param_vat-marża                                       object
# param_kategoria                                       object
# param_co2-emissions                                   object
# param_leasing                                         object
# param_mileage                                         object
# param_zarejestrowany-jako-zabytek                     object
# param_napęd                                           object
# param_wartość-wykupu                                  object
# param_typ                                             object
# param_metalik                                         object
# param_pierwszy-właściciel                             object
# param_skrzynia-biegów                                 object
# param_vat-discount                                    object
# param_no-accident                                     object
# param_liczba-pozostałych-rat                          object
# param_particle-filter                                 object
# param_zarejestrowany-w-polsce                         object
# param_oferta-od                                       object
# param_moc                                             int64
# param_make                                            object
# param_kraj-pochodzenia                                object
# param_engine-power                                    object
# param_year                                            object
# param_serwisowany-w-aso                               object
# param_rodzaj-paliwa                                   object
# param_możliwość-finansowania                          object
# param_registered-in-poland                            object
# param_transmission                                    object
# param_miesięczna-rata                                 object
# param_kod-silnika                                     object
# param_version                                         object
# param_opłata-początkowa                               object
# param_model_pojazdu                                   object
# param_pojemność-skokowa                               int64
# param_kierownica-po-prawej-(anglik)                   object
# param_fuel-type                                       object
# param_vat-free                                        object
# param_acrylic                                         object
# param_damaged                                         object
# param_door-count                                      object
# param_tuning                                          object
# param_filtr-cząstek-stałych                           object
# param_nr-of-seats                                     object
# param_kolor                                           object
# param_engine-capacity                                 object
# param_pearl                                           object
# param_stan                                            object
# param_wersja                                          object
# param_emisja-co2                                      object
# param_body-type                                       object
# param_matowy                                          object
# param_bezwypadkowy                                    object
# param_akryl-(niemetalizowany)                         object
# param_monthly-payment-value                           object
# car_id                                                int64
# created_at__cat                                       int64
# price_currency__cat                                   int64
# price_details__cat                                    int64
# price_value__cat                                      int64
# seller_address__cat                                   int64
# seller_name__cat                                      int64
# seller_type__cat                                      int64
# feature_czujniki-parkowania-przednie__cat             int64
# feature_poduszka-powietrzna-chroniąca-kolana__cat     int64
# feature_kurtyny-powietrzne__cat                       int64
# feature_klimatyzacja-dwustrefowa__cat                 int64
# feature_światła-led__cat                              int64
# feature_czujnik-zmierzchu__cat                        int64
# feature_elektrycznie-ustawiane-lusterka__cat          int64
# feature_asr-(kontrola-trakcji)__cat                   int64
# feature_poduszka-powietrzna-kierowcy__cat             int64
# feature_cd__cat                                       int64
# feature_elektryczne-szyby-przednie__cat               int64
# feature_poduszka-powietrzna-pasażera__cat             int64
# feature_system-start-stop__cat                        int64
# feature_światła-do-jazdy-dziennej__cat                int64
# feature_komputer-pokładowy__cat                       int64
# feature_elektryczne-szyby-tylne__cat                  int64
# feature_klimatyzacja-manualna__cat                    int64
# feature_tapicerka-welurowa__cat                       int64
# feature_czujnik-deszczu__cat                          int64
# feature_światła-przeciwmgielne__cat                   int64
# feature_ogrzewanie-postojowe__cat                     int64
# feature_radio-niefabryczne__cat                       int64
# feature_regulowane-zawieszenie__cat                   int64
# feature_ogranicznik-prędkości__cat                    int64
# feature_zmieniarka-cd__cat                            int64
# feature_szyberdach__cat                               int64
# feature_isofix__cat                                   int64
# feature_asystent-pasa-ruchu__cat                      int64
# feature_alufelgi__cat                                 int64
# feature_bluetooth__cat                                int64
# feature_nawigacja-gps__cat                            int64
# feature_asystent-parkowania__cat                      int64
# feature_wspomaganie-kierownicy__cat                   int64
# feature_podgrzewana-przednia-szyba__cat               int64
# feature_przyciemniane-szyby__cat                      int64
# feature_elektrycznie-ustawiane-fotele__cat            int64
# feature_klimatyzacja-czterostrefowa__cat              int64
# feature_tuner-tv__cat                                 int64
# feature_poduszki-boczne-przednie__cat                 int64
# feature_tempomat-aktywny__cat                         int64
# feature_klimatyzacja-automatyczna__cat                int64
# feature_poduszki-boczne-tylne__cat                    int64
# feature_radio-fabryczne__cat                          int64
# feature_odtwarzacz-dvd__cat                           int64
# feature_czujniki-parkowania-tylne__cat                int64
# feature_łopatki-zmiany-biegów__cat                    int64
# feature_centralny-zamek__cat                          int64
# feature_dach-panoramiczny__cat                        int64
# feature_kamera-cofania__cat                           int64
# feature_immobilizer__cat                              int64
# feature_czujnik-martwego-pola__cat                    int64
# feature_gniazdo-sd__cat                               int64
# feature_podgrzewane-lusterka-boczne__cat              int64
# feature_podgrzewane-przednie-siedzenia__cat           int64
# feature_hak__cat                                      int64
# feature_abs__cat                                      int64
# feature_wielofunkcyjna-kierownica__cat                int64
# feature_światła-xenonowe__cat                         int64
# feature_gniazdo-usb__cat                              int64
# feature_tapicerka-skórzana__cat                       int64
# feature_gniazdo-aux__cat                              int64
# feature_esp-(stabilizacja-toru-jazdy)__cat            int64
# feature_alarm__cat                                    int64
# feature_podgrzewane-tylne-siedzenia__cat              int64
# feature_mp3__cat                                      int64
# feature_tempomat__cat                                 int64
# feature_hud-(wyświetlacz-przezierny)__cat             int64
# feature_elektrochromatyczne-lusterko-wsteczne__cat    int64
# feature_relingi-dachowe__cat                          int64
# feature_elektrochromatyczne-lusterka-boczne__cat      int64
# param_liczba-miejsc__cat                              int64
# param_uszkodzony__cat                                 int64
# param_marka-pojazdu__cat                              int64
# param_model__cat                                      int64
# param_engine-code__cat                                int64
# param_liczba_drzwi__cat                               int64
# param_first-registration__cat                         int64
# param_country-of-origin__cat                          int64
# param_pierwsza-rejestracja__cat                       int64
# param_gearbox__cat                                    int64
# param_przebieg__cat                                   int64
# param_faktura-vat__cat                                int64
# param_rok-produkcji__cat                              int64
# param_vin__cat                                        int64
# param_perłowy__cat                                    int64
# param_homologacja-ciężarowa__cat                      int64
# param_service-record__cat                             int64
# param_metallic__cat                                   int64
# param_leasing-concession__cat                         int64
# param_color__cat                                      int64
# param_financing-option__cat                           int64
# param_original-owner__cat                             int64
# param_vat-marża__cat                                  int64
# param_kategoria__cat                                  int64
# param_co2-emissions__cat                              int64
# param_leasing__cat                                    int64
# param_mileage__cat                                    int64
# param_zarejestrowany-jako-zabytek__cat                int64
# param_napęd__cat                                      int64
# param_wartość-wykupu__cat                             int64
# param_typ__cat                                        int64
# param_metalik__cat                                    int64
# param_pierwszy-właściciel__cat                        int64
# param_skrzynia-biegów__cat                            int64
# param_vat-discount__cat                               int64
# param_no-accident__cat                                int64
# param_liczba-pozostałych-rat__cat                     int64
# param_particle-filter__cat                            int64
# param_zarejestrowany-w-polsce__cat                    int64
# param_oferta-od__cat                                  int64
# param_moc__cat                                        int64
# param_make__cat                                       int64
# param_kraj-pochodzenia__cat                           int64
# param_engine-power__cat                               int64
# param_year__cat                                       int64
# param_serwisowany-w-aso__cat                          int64
# param_rodzaj-paliwa__cat                              int64
# param_możliwość-finansowania__cat                     int64
# param_registered-in-poland__cat                       int64
# param_transmission__cat                               int64
# param_miesięczna-rata__cat                            int64
# param_kod-silnika__cat                                int64
# param_version__cat                                    int64
# param_opłata-początkowa__cat                          int64
# param_model_pojazdu__cat                              int64
# param_pojemność-skokowa__cat                          int64
# param_kierownica-po-prawej-(anglik)__cat              int64
# param_fuel-type__cat                                  int64
# param_vat-free__cat                                   int64
# param_acrylic__cat                                    int64
# param_damaged__cat                                    int64
# param_door-count__cat                                 int64
# param_tuning__cat                                     int64
# param_filtr-cząstek-stałych__cat                      int64
# param_nr-of-seats__cat                                int64
# param_kolor__cat                                      int64
# param_engine-capacity__cat                            int64
# param_pearl__cat                                      int64
# param_stan__cat                                       int64
# param_wersja__cat                                     int64
# param_emisja-co2__cat                                 int64
# param_body-type__cat                                  int64
# param_matowy__cat                                     int64
# param_bezwypadkowy__cat                               int64
# param_akryl-(niemetalizowany)__cat                    int64
# param_monthly-payment-value__cat                      int64
# car_id__cat                                           int64
# param_przebieg_num                                    int64
# dtypes: bool(70), int64(159), int8(1), object(80)
# memory usage: 201.8+ MB

# %%
xgb_params = {'max_depth': 5,
              'n_estimators': 50,
              'learning_rate': 0.1,
              'seed': 2020
              }

# %%
model = xgb.XGBRegressor(**xgb_params)

# %%
feats = ['param_napęd__cat','param_rok-produkcji','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc','param_marka-pojazdu__cat',
         'param_typ__cat','feature_kamera-cofania__cat','param_pojemność-skokowa','seller_name__cat','param_kod-silnika__cat','param_model_pojazdu__cat',
         'feature_wspomaganie-kierownicy__cat','param_wersja__cat','feature_czujniki-parkowania-przednie__cat','feature_asystent-pasa-ruchu__cat','feature_system-start-stop__cat',
         'feature_regulowane-zawieszenie__cat','feature_światła-led__cat', 'param_przebieg_num']

# %%
run_model(model, feats)
# Out:
# [18:48:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:48:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-9312.544136473989, 69.39471346674082)

# %%
X = df[feats].values
y = df['price_value'].values

m = xgb.XGBRegressor(**xgb_params)
m.fit(X, y)

imp = PermutationImportance(m, random_state=2020).fit(X, y)
eli5.show_weights(imp, feature_names=feats)
# Out:
# [18:48:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4012
#
#                     &plusmn; 0.0057
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_rok-produkcji
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3036
#
#                     &plusmn; 0.0028
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_moc
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0672
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_przebieg_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0636
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_pojemność-skokowa
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0233
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_marka-pojazdu__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0163
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_napęd__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0136
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 seller_name__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0122
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_wersja__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.37%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0112
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_kod-silnika__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0097
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_typ__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0063
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 feature_czujniki-parkowania-przednie__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0060
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_skrzynia-biegów__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0058
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_faktura-vat__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0055
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_model_pojazdu__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0027
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 feature_kamera-cofania__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0026
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 feature_regulowane-zawieszenie__cat
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0023
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 feature_wspomaganie-kierownicy__cat
#             </td>
#         </tr>
#
#         <tr style="background-

# %%
# !git config --global user.email "m.zajac1988@gmail.com"
# !git config --global user.name "Mateusz"

# %%
cd '/content/drive/My Drive/Colab Notebooks/dw_matrix'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
# !git add matrix_two/day4_xgboost.ipynb

# %%
# !git commit -m 'Feature Engineering Warmup'
# Out:
# [master 6863e85] Feature Engineering Warmup
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite matrix_two/day4_xgboost.ipynb (92%)

# %%
# !git push -u origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 4.47 KiB | 762.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/mattzajac/dw_matrix.git
#    c88fce7..6863e85  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
